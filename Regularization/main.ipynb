# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the dataset

# %%
data = fetch_california_housing()
X = data.data
y = data.target

# %% [markdown]
# Scaling the dataset

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.2, random_state = 42)

# %%
normal_model = LinearRegression()
ridge = Ridge(alpha = 1.0)
lasso = Lasso(alpha = 0.1)

# %%
normal_model.fit(X_train,y_train)
ridge.fit(X_train,y_train)
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred_normal = normal_model.predict(X_test)
y_pred_ridge = ridge.predict(X_test)
y_pred_lasso = lasso.predict(X_test)

# %%
mse_normal = mean_squared_error(y_test,y_pred_normal)
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
mse_lasso = mean_squared_error(y_test, y_pred_lasso)

# %%
print(mse_normal)
print(mse_ridge)
print(mse_lasso)
# Out:
# 0.5558915986952444
# 0.5558512007367515
# 0.6795515190149223

# %%
plt.figure(figsize = (10,10))
plt.plot(normal_model.coef_,'o',label = 'Normal Model Coefficient')
plt.plot(ridge.coef_,'x',label = 'Ridge Coefficient')
plt.plot(lasso.coef_,'^', label = 'Lasso Coefficent')
plt.xlabel('Feature Index')
plt.ylabel('Coefficient Value')
plt.legend()
plt.show()
